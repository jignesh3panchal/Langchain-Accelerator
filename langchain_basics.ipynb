# %% [markdown]
# # 🦜 LangChain Basics — Beginner's Notebook
# ### by - *Ashu Mishra*
# ### Reach me out on : https://www.linkedin.com/in/ashumish/
# ---
#
# **What you'll learn today:**
# 1. How to talk to an AI model using Python
# 2. How to use Prompt Templates (reusable instructions for AI)
# 3. How to build a Chain (connect steps together like an assembly line)
# 4. How to get clean, structured output from AI
#
# **Don't worry if you don't understand every line of code.**
# Focus on *what* each block does, not *how* Python works.
#
# ---

# %% [markdown]
# ## 🔧 Step 1: Install the tools we need
#
# Think of this like installing apps on your phone before using them.
# We are installing **LangChain** and **OpenAI** libraries.
#
# > ⏱️ This may take 1-2 minutes. Wait for it to finish before moving ahead.

# %%
# !pip install langchain langchain-openai openai python-dotenv -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.4/542.4 kB 25.6 MB/s eta 0:00:00

# %% [markdown]
# ## 🔑 Step 2: Set your OpenAI API Key
#
# An **API Key** is like a password that lets us use OpenAI's AI model (GPT).
#
# > 📌 Your instructor will share the API key during the session.
# > Replace `YOUR_OPENAI_API_KEY` below with the key shared with you.

# %%
import os

# 👇 Paste your API key here (between the quotes)
os.environ["OPENAI_API_KEY"] = "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"

print("✅ API Key is set!")
# Out:
# ✅ API Key is set!

# %% [markdown]
# ## 🚀 Exercise 1
#
# 📋 **Task:**
# Copy the above code and print the following message:
#
# > ✨ **"Ready to learn LangChain now!"** ✨
#
# ---
#
# 💡 **Your Goal:**
# Make sure your code successfully displays the message below 👇
#
# ```python
# print("Ready to learn LangChain now!")

# %%
import os

# 👇 Paste your API key here (between the quotes)
os.environ["OPENAI_API_KEY"] = "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"
#"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"

print("✅ Ready to learn LangChain now!")
# Out:
# ✅ Ready to learn LangChain now!

# %% [markdown]
# ---
#
# ## 🤖 Part 1: Talking to the AI Model
#
# ### What is an LLM?
#
# **LLM = Large Language Model** — it's the brain behind tools like ChatGPT.
#
# **Real-life analogy:**
# Imagine you have a very smart assistant sitting in a room.
# You pass a note through a slot → they read it → they write a reply → they pass it back.
#
# That's exactly what we're doing with code!
#
# ```
# You (Python code) → send a message → LLM reads it → LLM replies → you get the answer
# ```
#
# ![image.png](data:image/png;base64,...)
#
#
# Watch more about LLM : https://www.youtube.com/watch?v=LPZh9BOjkQs

# %%
from langchain_openai import ChatOpenAI

# Create the AI model (we're using GPT-4o-mini — fast and affordable)
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# Send a message to the AI and get a response
response = llm.invoke("What is the difference between an LLM and Agentic AI?")

# Print the response
print(response.content)
# Out:
# The terms "LLM" (Large Language Model) and "Agentic AI" refer to different concepts in the field of artificial intelligence.
#
# ### Large Language Model (LLM)
# - **Definition**: An LLM is a type of artificial intelligence model that is designed to understand and generate human language. These models are trained on vast amounts of text data and utilize deep learning techniques, particularly transformer architectures, to process and produce language.
# - **Functionality**: LLMs are primarily focused on tasks such as text generation, translation, summarization, and answering questions based on the context they were trained on. They generate text based on patterns learned from the training data, but they do not possess understanding, beliefs, or intentions.
# - **Examples**: GPT-3, BERT, and T5 are examples of LLMs that can generate coherent text and respond to user prompts.
#
# ### Agentic AI
# ...

# %% [markdown]
# ## 🤖 Exercise 2
#
# 📋 **Task:**
# Ask the following questions and understand the concepts:
#
# > ✨ **"What is Agentic AI?"**
# > ✨ **"What is the difference between an LLM and Agentic AI?"**
# > ✨ **"Give me the latest news around AI ?"**
#
# ---
#
# 💡 **Your Goal:**
# Make sure you clearly explore and learn the answers to these questions 👇
#
# ```text
# What is Agentic AI?
# What is the difference between LLM and Agentic AI?
# Give me the latest news around AI ?

# %% [markdown]
# ### 🌡️ What is `temperature`?
#
# | Temperature | Behaviour | Use Case |
# |-------------|-----------|----------|
# | `0.0` | Very predictable, always same answer | Maths, factual questions |
# | `0.7` | Creative but sensible | Most everyday tasks |
# | `1.0` | Very creative, sometimes unpredictable | Storytelling, brainstorming |
#
# Think of it like a **creativity dial** on your AI assistant.
#
# More about temperature : https://youtu.be/q4ks_aUgGT4?si=4vSi78fKoiAnI8z0

# %% [markdown]
# ## 🎨 Exercise 3
#
# 📋 **Task:**
# Use the code below and tweak it to generate different types of responses:
#
# > ✨ **Write a poem** 📝
# > ✨ **Write an answer about the distance between Earth and Moon** 🌍🌕
#
# ---
#
# 💡 **Your Goal:**
# Modify the **prompt** and experiment with the **temperature** to observe how responses change 👇
#
# ```python
# from langchain_openai import ChatOpenAI
#
# # Try changing temperature (e.g., 0.2, 0.7, 1.0) 🔥
# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
#
# # ✏️ Modify the prompt for different tasks
#
# # Example 1: Poem
# response = llm.invoke("Write a short creative poem about the moon.")
#
# # Example 2: Informational answer
# # response = llm.invoke("What is the distance between Earth and the Moon? Explain simply.")
#
# print(response.content)

# %%
from langchain_openai import ChatOpenAI

# Try changing temperature (e.g., 0.2, 0.7, 1.0) 🔥
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# ✏️ Modify the prompt for different tasks

# Example 1: Poem
response = llm.invoke("Write a short creative poem about the moon.")

# Example 2: Informational answer
# response = llm.invoke("What is the distance between Earth and the Moon? Explain simply.")

print(response.content)
# Out:
# In the velvet cloak of night,
# The moon hangs high, a silver light,
# A whispered secret, soft and clear,
# A guardian of dreams, drawing near.
#
# She dances on the ocean's crest,
# A shimmering pearl, the world’s behest,
# With gentle beams that kiss the trees,
# And stir the heart like a summer breeze.
#
# Her face, a canvas, stories told,
# Of lovers' sighs and nights of old,
# In shadows deep, she weaves her spell,
# A timeless tale, a magic well.
#
# So gaze upon her, lost in thought,
# In her embrace, all worries caught,
# For in her glow, we find our tune,
# The world awakens, cradled by the moon.

# %% [markdown]
# ---
#
# ## 📝 Part 2: Prompt Templates
#
# ### What is a Prompt Template?
#
# Imagine you work in HR and you write offer letters every week.
# Instead of writing from scratch each time, you create a **template**:
#
# ```
# Dear {candidate_name},
# We are pleased to offer you the role of {job_role} at a salary of {salary}.
# ```
#
# You just fill in the blanks each time. That's exactly what a **Prompt Template** does!
#
# It's a reusable message with **placeholders** that you fill in dynamically.

# %%
from langchain_core.prompts import ChatPromptTemplate
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
# Create a template with a placeholder {topic}
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a ANGRY teacher who explains things in very COMPLEX terms IN HNDI."),
    ("human", "Explain {topic} in 3 bullet points. Use simple language and a real-life example.")
])

# Now fill in the placeholder and see the final prompt
formatted_prompt = prompt_template.format_messages(topic="Machine Learning")
print("--- The prompt sent to AI ---")
for msg in formatted_prompt:
    print(f"[{msg.type.upper()}]: {msg.content}")
# Out:
# --- The prompt sent to AI ---
# [SYSTEM]: You are a ANGRY teacher who explains things in very COMPLEX terms IN HNDI.
# [HUMAN]: Explain Machine Learning in 3 bullet points. Use simple language and a real-life example.

# %%
# Now let's actually send this prompt to the AI and get a response
response = llm.invoke(formatted_prompt)
print(response.content)
# Out:
# मुझे माफ कीजिएगा, लेकिन मैं सरल भाषा में नहीं समझा सकता। मशीन लर्निंग एक अत्यंत जटिल विषय है, जिसे समझने के लिए गहरे ज्ञान की आवश्यकता होती है। फिर भी, मैं आपको इसे जटिलता के साथ समझाने का प्रयास करता हूं:
#
# 1. **आंकड़ों का विश्लेषण**: मशीन लर्निंग का मूल उद्देश्य डेटा के विशाल सेट का गहन विश्लेषण करना है, जिसमें विभिन्न विशेषताओं का अध्ययन करना शामिल है। यह प्रक्रिया न केवल डेटा के पैटर्न को पहचानने में सहायक होती है, बल्कि भविष्यवाणियों के लिए एक सांकेतिक मॉडल तैयार करती है।
#
# 2. **स्वायत्तता का विकास**: मशीन लर्निंग एल्गोरिदम स्वायत्तता की दिशा में अग्रसर होते हैं, जिससे वे बिना किसी मानव हस्तक्षेप के अनुभव से सीख सकते हैं। यह प्रक्रिया निरंतरता में होती है, जहां मशीन अपने प्रदर्शन को समायोजित करती है और बेहतर परिणाम उत्पन्न करने के लिए अपने पूर्ववर्ती डेटा से सबक लेती है।
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 🛒 Exercise 4
#
# 📋 **Task:**
# Update the prompt template so the AI behaves like an **ecommerce expert** and explains the **top 3 issues customers face** at a given journey stage.
#
# > ✨ **System Prompt:**
# > You are an ecommerce expert, who tells the user top 3 issues customer face depending upon the journey they are at.
#
# > ✨ **Human Prompt:**
# > Explain issues in the journey **{topic}** in 3 bullet points. Use simple language and a real-life example.
#
# ---
#
# 💡 **Your Goal:**
# Replace the original prompts and test the template with:
#
# ```python
# topic = "Login Page"

# %% [markdown]
# ## 🎭 Exercise 5
#
# 📋 **Task:**
# Create a more **creative and expressive response** by increasing the temperature of the model.
#
# > ✨ **System Prompt:**
# > You are a creative storyteller who explains things in a fun, imaginative, and engaging way.
#
# > ✨ **Human Prompt:**
# > Explain {topic} as a short story with characters and emotions. Keep it simple and engaging.
#
# ---
#
# 💡 **Your Goal:**
# Set a **higher temperature (e.g., 0.9 or 1.0)** and observe how the response becomes more creative 👇
#
#
#
# # Try with this topic
# ```python
# topic = "Artificial Intelligence"

# %% [markdown]
# ---
#
# ## ⛓️ Part 3: Chains — The Assembly Line
#
# ### What is a Chain?
#
# Think of a **Zomato order**:
#
# ```
# You place order → Restaurant cooks → Delivery picks up → You receive food
# ```
#
# Each step happens **in sequence**, and the output of one step becomes the input of the next.
#
# A **LangChain Chain** works the same way:
#
# ```
# Prompt Template → LLM → Output Parser
# ```
#
# In LangChain, we connect steps using the **pipe operator** `|`
# *(it literally means "pass this to the next step")*

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Step 1: Define the prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful career advisor."),
    ("human", "Give me 3 tips for someone working as a {job_role}. Keep it short and practical.")
])

# Step 2: Define the output parser (converts AI response to plain text)
output_parser = StrOutputParser()

# Step 3: Define the llm
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# Step 4: Connect them into a chain using the pipe | operator
chain = prompt | llm | output_parser

# Step 5: Run the chain!
result = chain.invoke({"job_role": "Data science"})
print(result)
# Out:
# Sure! Here are three practical tips for someone working in data science:
#
# 1. **Master Data Cleaning**: Spend time honing your data wrangling skills. High-quality insights stem from clean, well-prepared data. Familiarize yourself with libraries like Pandas and tools like OpenRefine.
#
# 2. **Stay Updated on Tools and Trends**: Data science is rapidly evolving. Regularly explore new libraries, frameworks, and methodologies (e.g., TensorFlow, PyTorch) to keep your skills relevant and competitive.
#
# 3. **Communicate Effectively**: Practice translating complex findings into clear, actionable insights for non-technical stakeholders. Use visualizations and storytelling techniques to make your data impactful.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# The beauty of a chain — reuse it with different inputs!
# Same chain, different job role

result2 = chain.invoke({"job_role": "Data Analyst"})
print(result2)
# Out:
# Here are three practical tips for a Data Analyst:
#
# 1. **Master Data Visualization Tools**: Familiarize yourself with tools like Tableau, Power BI, or Looker to effectively communicate insights through compelling visuals.
#
# 2. **Enhance SQL Skills**: Strengthen your SQL knowledge to efficiently manipulate and query databases, as it’s essential for extracting valuable data.
#
# 3. **Stay Curious and Learn Continuously**: Keep up with industry trends and new analytical techniques by taking online courses, attending webinars, and participating in data analytics communities.

# %% [markdown]
# ## 🧩 Exercise 6
#
# 📋 **Task:**
# Modify the prompt so the AI gives **career advice for a different role and perspective**.
#
# ---
#
# 💡 **What you need to change:**
#
# - Change the **system prompt** to:
#   👉 "You are a startup mentor who gives practical business advice."
#
# - Change the **human prompt** to:
#   👉 Ask for **3 mistakes to avoid** instead of tips
#
# - Change the input:
#   👉 job_role = "Founder"
#
# ---
#
# 🎯 **Expected Outcome:**
#
# 🧠 The AI should now:
# - Act like a **startup mentor** 🧑‍💼
# - Give **mistakes to avoid** ❌ instead of tips
# - Tailor advice for a **Founder** 🚀
#
# ---
#
# 🔥 **Goal:** Understand how small prompt changes completely shift output

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Step 1: Define the prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a startup mentor who gives practical business advice."),
    ("human", "Give me 3 mistakes to avoid a {job_role}. Keep it short and practical.")
])

# Step 2: Define the output parser (converts AI response to plain text)
output_parser = StrOutputParser()

# Step 3: Define the llm
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# Step 4: Connect them into a chain using the pipe | operator
chain = prompt | llm | output_parser

# Step 5: Run the chain!
result = chain.invoke({"job_role": "Founder"})
print(result)
# Out:
# 1. **Neglecting Market Research**: Avoid launching without thorough research on your target audience and competitors. Validate your idea through surveys and focus groups to ensure there’s a genuine need.
#
# 2. **Underestimating Cash Flow**: Ensure you have a solid financial plan. Many startups fail due to cash flow issues. Keep a close eye on expenses and maintain a runway that covers at least 6-12 months of operation.
#
# 3. **Ignoring Team Dynamics**: Build a strong team culture from the start. Avoid hiring solely for skills; prioritize cultural fit and communication. A cohesive team is essential for navigating the ups and downs of startup life.

# %% [markdown]
# ## 🔥 Exercise 7
#
# 📋 **Task:**
# Experiment with **temperature** and observe how responses change.
#
# ---
#
# 💡 **What you need to change:**
#
# - Run the same code **3 times** with:
#   - Temperature = `0.2`
#   - Temperature = `0.7`
#   - Temperature = `1.0`
#
# - Keep everything else **exactly the same**
#
# ---
#
# 🎯 **Observe carefully:**
#
# 🧠 At **0.2**:
# - Output should be more **safe and predictable** 📊
#
# 🎨 At **1.0**:
# - Output should be more **creative and varied** 🌈
#
# ---
#
# 🔥 **Goal:**
# Understand how temperature controls **creativity vs consistency**

# %% [markdown]
# ## 🔗 Exercise 8
#
# 📋 **Task:**
# Fix the chain connection so the pipeline works correctly.
#
# ---
#
# 💡 **What you need to do:**
#
# - You are given:
#   - Prompt 🧩
#   - LLM 🤖
#   - Output Parser 📝
#
# - Complete the chain using the `|` operator
#
# ---
#
# 💻 **Code:**
#
# ```python
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_openai import ChatOpenAI
#
# prompt = ChatPromptTemplate.from_messages([
#     ("system", "You are a helpful career advisor."),
#     ("human", "Give me 3 tips for someone working as a {job_role}.")
# ])
#
# output_parser = StrOutputParser()
# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
#
# # ✏️ Fill this line correctly
# chain = ______________________________
#
# result = chain.invoke({"job_role": "Designer"})
# print(result)

# %% [markdown]
# ---
#
# ## 📦 Part 4: Output Parsers — Getting Clean Output
#
# ### What is an Output Parser?
#
# AI models return text. But sometimes you need a **list**, or a **specific format**.
#
# **Real-life analogy:**
# You ask your assistant: *"Give me the top 5 cities to visit in India."*
# They say: *"Mumbai, Delhi, Jaipur, Goa, Varanasi."* — that's a comma-separated list!
#
# An **Output Parser** automatically converts AI's text into the format you need.

# %% [markdown]
# ## 📋 Case Study: Making AI Output Usable by a System
#
# ### The Problem
#
# You are building an AI agent for a product team.
#
# The agent needs to:
# 1. Get a list of AI tools from the AI
# 2. Pass that list to the next step — save to database,
#    show in dashboard, or trigger another workflow
#
# Simple enough. Let's try it.

# %% [markdown]
# ### 🔴 Step 1 — Primitive Solution (No Parser)
#
# Let's ask the AI for the list the straightforward way.
# Run this and look carefully at the output.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "List 5 popular AI tools used in product management.")
])

chain = prompt | llm

result = chain.invoke({})

print("Type of result:", type(result))
print("\nOutput:")
print(result.content)
# Out:
# Type of result: <class 'langchain_core.messages.ai.AIMessage'>
#
# Output:
# Here are five popular AI tools commonly used in product management:
#
# 1. **Jira with AI Plugins**: Jira is a widely used project management tool that integrates various AI plugins to help with task prioritization, sprint planning, and project tracking. AI enhancements can automate repetitive tasks and provide insights into team performance.
#
# 2. **Aha!**: Aha! is a product roadmap software that uses AI to help product managers gather customer feedback, prioritize features, and visualize product strategies. It provides analytics to inform decision-making and align teams.
#
# 3. **Trello with Butler**: Trello is a visual collaboration tool that can be enhanced with Butler, an AI automation tool. Butler allows users to automate workflows, set up rules, and manage tasks more efficiently, making it easier for product managers to track progress.
#
# ...

# %% [markdown]
# ### ❌ Why this output is a problem
#
# Look at what we got:
#
# - `Type of result` → `AIMessage`
#   This is one big blob of text. Not a list.
#
# - The AI replied like a human — full sentences,
#   explanations, commas everywhere.
#
# Now ask yourself:
#
# | Question | Answer |
# |---|---|
# | Can I save each tool separately to a database? | ❌ No |
# | Can the next agent step loop through this? | ❌ No |
# | Will I get the same format every time I run it? | ❌ No |
# | Can a dashboard read this automatically? | ❌ No |
#
# **The AI talked like a human. But machines need
# to talk to other machines.**
#
# We need to fix this.

# %% [markdown]
# ### 🟢 Step 2 — Introducing the Output Parser
#
# We are going to make two small changes to the code:
#
# 1. Add a parser — `CommaSeparatedListOutputParser()`
# 2. Ask the parser to give the AI format instructions
#    before it replies — `parser.get_format_instructions()`
#
# That's it. Same question. Same AI. Watch what changes.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# Change 1 — create the parser
parser = CommaSeparatedListOutputParser()

# Change 2 — get format instructions from the parser
format_instructions = parser.get_format_instructions()

print("What the parser tells the AI:")
print(format_instructions)
# Out:
# What the parser tells the AI:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %% [markdown]
# > 👆 Read that format instruction carefully.
# > The parser is telling the AI:
# > *"Don't give me a paragraph. Give me values
# > separated by commas. Like this: foo, bar, baz"*
# >
# > Now let's pass this instruction into the prompt
# > and run the chain.

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("human", "List 5 popular AI tools used in product management.\n{format_instructions}")
])
# Change 3 — add parser at the end of the chain
chain = prompt | llm | parser

result = chain.invoke({"format_instructions": format_instructions})

print("Type of result:", type(result))
print("\nAI Tools:")
for i, tool in enumerate(result, 1):
    print(f"  {i}. {tool}")
# Out:
# Type of result: <class 'list'>
#
# AI Tools:
#   1. Airtable
#   2. Trello
#   3. JIRA
#   4. Productboard
#   5. Notion

# %% [markdown]
# ### 🔍 What Changed — Exactly
#
# Only 3 lines were added. Nothing else touched.
#
# | What we added | Why |
# |---|---|
# | `CommaSeparatedListOutputParser()` | Created the parser |
# | `parser.get_format_instructions()` | Told the AI how to format its reply |
# | `\| parser` at end of chain | Told the chain to clean the output |

# %% [markdown]
# ### ⚙️ How That Change Affected the Output
#
# The parser did two jobs — one BEFORE the AI replied,
# one AFTER.
#
# **Job 1 — BEFORE the AI replied:**
# The parser gave the AI a clear instruction:
# *"Reply in comma separated format only.
# No sentences. No explanation."*
# The AI now knew exactly what to return.
#
# **Job 2 — AFTER the AI replied:**
# The parser took the AI's clean comma separated reply:
# `Jira, Asana, Notion, Airtable, Productboard`
# And split it into a proper Python list:
# `["Jira", "Asana", "Notion", "Airtable", "Productboard"]`
#
# ---
#
# **The result:**
#
# | | Without Parser | With Parser |
# |---|---|---|
# | Type | `AIMessage` — blob of text | `list` — usable data |
# | Loopable? | ❌ No | ✅ Yes |
# | Saveable to database? | ❌ No | ✅ Yes |
# | Consistent every run? | ❌ No | ✅ Yes |
# | System digestible? | ❌ No | ✅ Yes |
#
# **One parser. Three lines. Completely different result.**

# %% [markdown]
# ---
#
# ## 🎯 Quick Recap — What We Learned
#
# | Concept | What it does | Real-life analogy |
# |---------|-------------|-------------------|
# | **LLM** | The AI brain that generates text | Smart assistant in a room |
# | **Prompt Template** | Reusable instructions with placeholders | HR offer letter template |
# | **Chain** | Connects steps in sequence | Zomato delivery pipeline |
# | **Output Parser** | Converts AI text to clean format | Formatting a raw answer |
#
# The magic formula:
# ```
# chain = prompt_template | llm | output_parser
# result = chain.invoke({"your_variable": "your_value"})
# ```
#
# ---

# %% [markdown]
# ## ✏️ Exercise — Your Turn!
#
# ### Change only these 3 things:
#
# | # | What to change | Hint |
# |---|---|---|
# | 1 | System message | Tell AI it is an HR assistant |
# | 2 | Human message | Ask for top 5 skills for {job_role} |
# | 3 | Your job role | Put your own role here |
#
# Do not touch anything else.

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import CommaSeparatedListOutputParser

parser = CommaSeparatedListOutputParser()
format_instructions = parser.get_format_instructions()

# 👇 Change 3: put your job role here
job_role = "Marketing Manager"

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful HR assistant."),  # 👈 Change 1
    ("human", "List 5 popular skills.\n{format_instructions}")  # 👈 Change 2: ask for top 5 skills for the job_role variable above
])

chain = prompt | llm | parser

# Do not touch this
result = chain.invoke({"format_instructions": format_instructions})

print(f"Results for: {job_role}")
print("\n Top Skills:")  # 👈 rename this too if you like
for i, item in enumerate(result, 1):
    print(f"  {i}. {item}")
# Out:
# Results for: Marketing Manager
#
#  Top Skills:
#   1. communication
#   2. problem-solving
#   3. teamwork
#   4. adaptability
#   5. critical thinking

# %% [markdown]
# # 🚀 Class 2 - BS: LangChain (Part 2)
#
# ---
#
# ### 📅 Date: 11th April, 2026
